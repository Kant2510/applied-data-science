# %%
# !pip install river pandas kagglehub
# Out:
# Collecting river
#   Downloading river-0.24.2-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (8.3 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.12/dist-packages (1.0.0)
# Requirement already satisfied: scipy<2,>=1.16 in /usr/local/lib/python3.12/dist-packages (from river) (1.16.3)
# Collecting numpy<3,>=2.3.4 (from river)
#   Downloading numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in /usr/local/lib/python3.12/dist-packages (from kagglehub) (0.1.20)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kagglehub) (26.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kagglehub) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kagglehub) (4.67.3)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kagglesdk<1.0,>=0.1.14->kagglehub) (5.29.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2026.4.22)
# Downloading river-0.24.2-cp312-cp312-manylinux_2_28_x86_64.whl (4.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 31.5 MB/s eta 0:00:00
# Downloading numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 59.2 MB/s eta 0:00:00
# Installing collected packages: numpy, river
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.4.4 which is incompatible.
# Successfully installed numpy-2.4.4 river-0.24.2

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
# !kaggle datasets list
# Out:
# You must authenticate before you can call the Kaggle API.
# Follow the instructions to authenticate at: https://github.com/Kaggle/kaggle-cli/blob/main/docs/README.md#authentication

# %%
# !kaggle datasets download -d ealaxi/paysim1
# !unzip paysim1.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ealaxi/paysim1
# License(s): CC-BY-SA-4.0
# Downloading paysim1.zip to /content
# 100% 178M/178M [00:01<00:00, 142MB/s]
#
# Archive:  paysim1.zip
#   inflating: PS_20174392719_1491204439457_log.csv

# %%
import pandas as pd
import numpy as np
from collections import deque
from river import stream, metrics, preprocessing, forest, drift
import random

# =========================
# LOAD DATA
# =========================
df = pd.read_csv("PS_20174392719_1491204439457_log.csv")
df = df.sort_values("step").reset_index(drop=True)

df["type_encoded"]      = df["type"].astype("category").cat.codes
df["orig_balance_diff"] = df["newbalanceOrig"] - df["oldbalanceOrg"]
df["dest_balance_diff"] = df["newbalanceDest"] - df["oldbalanceDest"]
df["amount_ratio"]      = df["amount"] / (df["oldbalanceOrg"] + 1)

X = df.drop(columns=["isFraud","isFlaggedFraud","nameOrig","nameDest","type","step"])
y = df["isFraud"]

print(f"Total rows:  {len(df):,}")
print(f"Fraud rows:  {df['isFraud'].sum():,}")
print(f"Fraud rate:  {df['isFraud'].mean()*100:.3f}%")

# =========================
# TRUE BASELINE — ROSFD paper
# ARF + ADWIN
# =========================
class ROSFD_Baseline:
    name = "ROSFD(paper)"
    def __init__(self):
        self.drift_count = 0
        self.adwin       = drift.ADWIN()
        self.model       = (preprocessing.StandardScaler() |
                           forest.ARFClassifier(n_models=10, seed=42))

    def learn_predict(self, x, y_true):
        y_proba = self.model.predict_proba_one(x).get(1, 0.0)
        y_pred  = self.model.predict_one(x)

        self.adwin.update(int(y_pred != y_true))
        if self.adwin.drift_detected:
            self.drift_count += 1

        self.model.learn_one(x, y_true)

        return y_pred, y_proba
# Out:
# Total rows:  6,362,620
# Fraud rows:  8,213
# Fraud rate:  0.129%

# %%
import pandas as pd
from river import stream, metrics

# STREAM DATASET
dataset = stream.iter_pandas(X, y)

# INIT MODEL
model = ROSFD_Baseline()

# metrics
auc = metrics.ROCAUC()
f1 = metrics.F1()
recall = metrics.Recall()
precision = metrics.Precision()

fraud_seen = 0
normal_seen = 0

# RUN STREAM
for i, (x_i, y_i) in enumerate(dataset):

    y_pred, y_proba = model.learn_predict(x_i, y_i)

    # update metrics
    auc.update(y_i, y_proba)
    f1.update(y_i, y_pred)
    recall.update(y_i, y_pred)
    precision.update(y_i, y_pred)

    # count classes
    if y_i == 1:
        fraud_seen += 1
    else:
        normal_seen += 1

    # logging
    if i % 100_000 == 0 and i > 0:
        print(f"\n{'='*50}")
        print(f"Step: {i:,}")
        print(f"Fraud seen: {fraud_seen:,}")
        print(f"Normal seen: {normal_seen:,}")
        print(f"{auc}")
        print(f"{f1}")
        print(f"{recall}")
        print(f"{precision}")
        print(f"Drifts:    {model.drift_count}")

# FINAL RESULT
print(f"\n{'='*50}")
print("FINAL RESULT")
print(f"{'='*50}")
print(f"{auc}")
print(f"{f1}")
print(f"{recall}")
print(f"{precision}")
print(f"Drifts:    {model.drift_count}")
print(f"Fraud seen: {fraud_seen:,}")
print(f"Normal seen: {normal_seen:,}")
# Out:
# ==================================================
# Step: 100,000
# Fraud seen: 116
# Normal seen: 99,885
# ROCAUC: 60.30%
# F1: 3.39%
# Recall: 1.72%
# Precision: 100.00%
# Drifts:    1
#
# ==================================================
# Step: 200,000
# Fraud seen: 147
# Normal seen: 199,854
# ROCAUC: 58.14%
# F1: 2.68%
# Recall: 1.36%
# Precision: 100.00%
# Drifts:    1
#
# ==================================================
# Step: 300,000
# Fraud seen: 181
# Normal seen: 299,820
# ROCAUC: 56.61%
# F1: 2.19%
# Recall: 1.10%
# Precision: 100.00%
# Drifts:    1
#
# ==================================================
# Step: 400,000
# Fraud seen: 206
# Normal seen: 399,795
# ROCAUC: 55.81%
# F1: 1.92%
# Recall: 0.97%
# Precision: 100.00%
# Drifts:    1
#
# ==================================================
# Step: 500,000
# Fraud seen: 233
# Normal seen: 499,768
# ROCAUC: 55.14%
# F1: 1.70%
# Recall: 0.86%
# Precision: 100.00%
# Drifts:    1
#
# ==================================================
# Step: 600,000
# Fraud seen: 361
# Normal seen: 599,640
# ROCAUC: 61.76%
# F1: 22.60%
# Recall: 12.74%
# Precision: 100.00%
# Drifts:    4
#
# ==================================================
# Step: 700,000
# Fraud seen: 417
# Normal seen: 699,584
# ROCAUC: 60.18%
# F1: 19.87%
# Recall: 11.03%
# Precision: 100.00%
# Drifts:    4
#
# ==================================================
# Step: 800,000
# Fraud seen: 460
# Normal seen: 799,541
# ROCAUC: 59.23%
# F1: 18.18%
# Recall: 10.00%
# Precision: 100.00%
# Drifts:    4
#
# ==================================================
# Step: 900,000
# Fraud seen: 498
# Normal seen: 899,503
# ROCAUC: 58.52%
# F1: 16.91%
# Recall: 9.24%
# Precision: 100.00%
# Drifts:    4
#
# ==================================================
# Step: 1,000,000
# Fraud seen: 535
# Normal seen: 999,466
# ROCAUC: 57.94%
# F1: 15.83%
# Recall: 8.60%
# Precision: 100.00%
# Drifts:    4
#
# ==================================================
# Step: 1,100,000
# Fraud seen: 1,488
# Normal seen: 1,098,513
# ROCAUC: 80.17%
# F1: 68.78%
# Recall: 53.29%
# Precision: 96.94%
# Drifts:    10
#
# ==================================================
# Step: 1,200,000
# Fraud seen: 1,518
# Normal seen: 1,198,483
# ROCAUC: 79.57%
# F1: 67.89%
# Recall: 52.24%
# Precision: 96.94%
# Drifts:    10
#
# ==================================================
# Step: 1,300,000
# Fraud seen: 1,548
# Normal seen: 1,298,453
# ROCAUC: 79.00%
# F1: 67.03%
# Recall: 51.23%
# Precision: 96.94%
# Drifts:    10
#
# ==================================================
# Step: 1,400,000
# Fraud seen: 1,572
# Normal seen: 1,398,429
# ROCAUC: 78.56%
# F1: 66.36%
# Recall: 50.45%
# Precision: 96.94%
# Drifts:    10
#
# ==================================================
# Step: 1,500,000
# Fraud seen: 1,608
# Normal seen: 1,498,393
# ROCAUC: 77.92%
# F1: 65.38%
# Recall: 49.32%
# Precision: 96.94%
# Drifts:    10
#
# ==================================================
# Step: 1,600,000
# Fraud seen: 1,764
# Normal seen: 1,598,237
# ROCAUC: 78.25%
# F1: 64.89%
# Recall: 49.04%
# Precision: 95.90%
# Drifts:    13
#
# ==================================================
# Step: 1,700,000
# Fraud seen: 1,812
# Normal seen: 1,698,189
# ROCAUC: 77.50%
# F1: 63.74%
# Recall: 47.74%
# Precision: 95.90%
# Drifts:    13
#
# ==================================================
# Step: 1,800,000
# Fraud seen: 1,862
# Normal seen: 1,798,139
# ROCAUC: 76.76%
# F1: 62.59%
# Recall: 46.46%
# Precision: 95.90%
# Drifts:    14
#
# ==================================================
# Step: 1,900,000
# Fraud seen: 1,890
# Normal seen: 1,898,111
# ROCAUC: 76.37%
# F1: 61.96%
# Recall: 45.77%
# Precision: 95.90%
# Drifts:    14
#
# ==================================================
# Step: 2,000,000
# Fraud seen: 2,036
# Normal seen: 1,997,965
# ROCAUC: 76.27%
# F1: 61.92%
# Recall: 45.68%
# Precision: 96.07%
# Drifts:    16
#
# ==================================================
# Step: 2,100,000
# Fraud seen: 2,063
# Normal seen: 2,097,938
# ROCAUC: 75.93%
# F1: 61.37%
# Recall: 45.08%
# Precision: 96.07%
# Drifts:    16
#
# ==================================================
# Step: 2,200,000
# Fraud seen: 2,103
# Normal seen: 2,197,898
# ROCAUC: 75.43%
# F1: 60.57%
# Recall: 44.22%
# Precision: 96.07%
# Drifts:    16
#
# ==================================================
# Step: 2,300,000
# Fraud seen: 2,134
# Normal seen: 2,297,867
# ROCAUC: 75.06%
# F1: 59.96%
# Recall: 43.58%
# Precision: 96.07%
# Drifts:    16
#
# ==================================================
# Step: 2,400,000
# Fraud seen: 2,262
# Normal seen: 2,397,739
# ROCAUC: 74.51%
# F1: 58.82%
# Recall: 42.44%
# Precision: 95.81%
# Drifts:    19
#
# ==================================================
# Step: 2,500,000
# Fraud seen: 2,278
# Normal seen: 2,497,723
# ROCAUC: 74.33%
# F1: 58.54%
# Recall: 42.14%
# Precision: 95.81%
# Drifts:    19
#
# ==================================================
# Step: 2,600,000
# Fraud seen: 2,316
# Normal seen: 2,597,685
# ROCAUC: 73.93%
# F1: 57.87%
# Recall: 41.45%
# Precision: 95.81%
# Drifts:    19
#
# ==================================================
# Step: 2,700,000
# Fraud seen: 2,351
# Normal seen: 2,697,650
# ROCAUC: 73.58%
# F1: 57.26%
# Recall: 40.83%
# Precision: 95.81%
# Drifts:    19
#
# ==================================================
# Step: 2,800,000
# Fraud seen: 2,451
# Normal seen: 2,797,550
# ROCAUC: 72.62%
# F1: 55.60%
# Recall: 39.17%
# Precision: 95.81%
# Drifts:    21
#
# ==================================================
# Step: 2,900,000
# Fraud seen: 2,567
# Normal seen: 2,897,434
# ROCAUC: 72.84%
# F1: 55.86%
# Recall: 39.54%
# Precision: 95.13%
# Drifts:    22
#
# ==================================================
# Step: 3,000,000
# Fraud seen: 2,619
# Normal seen: 2,997,382
# ROCAUC: 72.39%
# F1: 55.07%
# Recall: 38.76%
# Precision: 95.13%
# Drifts:    22
#
# ==================================================
# Step: 3,100,000
# Fraud seen: 2,653
# Normal seen: 3,097,348
# ROCAUC: 72.10%
# F1: 54.57%
# Recall: 38.26%
# Precision: 95.13%
# Drifts:    22
#
# ==================================================
# Step: 3,200,000
# Fraud seen: 2,799
# Normal seen: 3,197,202
# ROCAUC: 71.64%
# F1: 53.48%
# Recall: 37.33%
# Precision: 94.23%
# Drifts:    25
#
# ==================================================
# Step: 3,300,000
# Fraud seen: 2,853
# Normal seen: 3,297,148
# ROCAUC: 71.55%
# F1: 52.75%
# Recall: 36.63%
# Precision: 94.23%
# Drifts:    26
#
# ==================================================
# Step: 3,400,000
# Fraud seen: 2,877
# Normal seen: 3,397,124
# ROCAUC: 71.37%
# F1: 52.43%
# Recall: 36.32%
# Precision: 94.23%
# Drifts:    26
#
# ==================================================
# Step: 3,500,000
# Fraud seen: 2,905
# Normal seen: 3,497,096
# ROCAUC: 71.16%
# F1: 52.07%
# Recall: 35.97%
# Precision: 94.23%
# Drifts:    26
#
# ==================================================
# Step: 3,600,000
# Fraud seen: 2,969
# Normal seen: 3,597,032
# ROCAUC: 70.71%
# F1: 51.25%
# Recall: 35.20%
# Precision: 94.23%
# Drifts:    27
#
# ==================================================
# Step: 3,700,000
# Fraud seen: 3,139
# Normal seen: 3,696,862
# ROCAUC: 71.08%
# F1: 51.11%
# Recall: 35.07%
# Precision: 94.18%
# Drifts:    29
#
# ==================================================
# Step: 3,800,000
# Fraud seen: 3,179
# Normal seen: 3,796,822
# ROCAUC: 70.89%
# F1: 50.64%
# Recall: 34.63%
# Precision: 94.18%
# Drifts:    31
#
# ==================================================
# Step: 3,900,000
# Fraud seen: 3,223
# Normal seen: 3,896,778
# ROCAUC: 70.76%
# F1: 50.14%
# Recall: 34.16%
# Precision: 94.18%
# Drifts:    31
#
# ==================================================
# Step: 4,000,000
# Fraud seen: 3,381
# Normal seen: 3,996,620
# ROCAUC: 70.93%
# F1: 50.05%
# Recall: 34.13%
# Precision: 93.82%
# Drifts:    34
#
# ==================================================
# Step: 4,100,000
# Fraud seen: 3,405
# Normal seen: 4,096,596
# ROCAUC: 70.78%
# F1: 49.80%
# Recall: 33.89%
# Precision: 93.82%
# Drifts:    34
#
# ==================================================
# Step: 4,200,000
# Fraud seen: 3,433
# Normal seen: 4,196,568
# ROCAUC: 70.61%
# F1: 49.50%
# Recall: 33.61%
# Precision: 93.82%
# Drifts:    34
#
# ==================================================
# Step: 4,300,000
# Fraud seen: 3,471
# Normal seen: 4,296,530
# ROCAUC: 70.39%
# F1: 49.10%
# Recall: 33.25%
# Precision: 93.82%
# Drifts:    34
#
# ==================================================
# Step: 4,400,000
# Fraud seen: 3,613
# Normal seen: 4,396,388
# ROCAUC: 70.38%
# F1: 48.93%
# Recall: 33.16%
# Precision: 93.30%
# Drifts:    37
#
# ==================================================
# Step: 4,500,000
# Fraud seen: 3,657
# Normal seen: 4,496,344
# ROCAUC: 70.13%
# F1: 48.49%
# Recall: 32.76%
# Precision: 93.30%
# Drifts:    37
#
# ==================================================
# Step: 4,600,000
# Fraud seen: 3,705
# Normal seen: 4,596,296
# ROCAUC: 69.87%
# F1: 48.03%
# Recall: 32.33%
# Precision: 93.30%
# Drifts:    37
#
# ==================================================
# Step: 4,700,000
# Fraud seen: 3,725
# Normal seen: 4,696,276
# ROCAUC: 69.76%
# F1: 47.83%
# Recall: 32.16%
# Precision: 93.30%
# Drifts:    37
#
# ==================================================
# Step: 4,800,000
# Fraud seen: 3,855
# Normal seen: 4,796,146
# ROCAUC: 69.94%
# F1: 48.12%
# Recall: 32.45%
# Precision: 93.08%
# Drifts:    39
#
# ==================================================
# Step: 4,900,000
# Fraud seen: 3,879
# Normal seen: 4,896,122
# ROCAUC: 69.87%
# F1: 47.90%
# Recall: 32.25%
# Precision: 93.08%
# Drifts:    39
#
# ==================================================
# Step: 5,000,000
# Fraud seen: 3,935
# Normal seen: 4,996,066
# ROCAUC: 69.75%
# F1: 47.40%
# Recall: 31.79%
# Precision: 93.08%
# Drifts:    39
#
# ==================================================
# Step: 5,100,000
# Fraud seen: 3,961
# Normal seen: 5,096,040
# ROCAUC: 69.67%
# F1: 47.16%
# Recall: 31.58%
# Precision: 93.08%
# Drifts:    39
#
# ==================================================
# Step: 5,200,000
# Fraud seen: 4,121
# Normal seen: 5,195,880
# ROCAUC: 69.90%
# F1: 47.46%
# Recall: 31.86%
# Precision: 92.99%
# Drifts:    42
#
# ==================================================
# Step: 5,300,000
# Fraud seen: 4,159
# Normal seen: 5,295,842
# ROCAUC: 69.72%
# F1: 47.14%
# Recall: 31.57%
# Precision: 92.99%
# Drifts:    42
#
# ==================================================
# Step: 5,400,000
# Fraud seen: 4,197
# Normal seen: 5,395,804
# ROCAUC: 69.54%
# F1: 46.82%
# Recall: 31.28%
# Precision: 92.99%
# Drifts:    42
#
# ==================================================
# Step: 5,500,000
# Fraud seen: 4,225
# Normal seen: 5,495,776
# ROCAUC: 69.41%
# F1: 46.59%
# Recall: 31.08%
# Precision: 92.99%
# Drifts:    42
#
# ==================================================
# Step: 5,600,000
# Fraud seen: 4,393
# Normal seen: 5,595,608
# ROCAUC: 69.49%
# F1: 46.84%
# Recall: 31.44%
# Precision: 91.82%
# Drifts:    45
#
# ==================================================
# Step: 5,700,000
# Fraud seen: 4,425
# Normal seen: 5,695,576
# ROCAUC: 69.35%
# F1: 46.58%
# Recall: 31.21%
# Precision: 91.82%
# Drifts:    45
#
# ==================================================
# Step: 5,800,000
# Fraud seen: 4,487
# Normal seen: 5,795,514
# ROCAUC: 69.08%
# F1: 46.10%
# Recall: 30.78%
# Precision: 91.82%
# Drifts:    46
#
# ==================================================
# Step: 5,900,000
# Fraud seen: 4,521
# Normal seen: 5,895,480
# ROCAUC: 68.94%
# F1: 45.84%
# Recall: 30.55%
# Precision: 91.82%
# Drifts:    46
#
# ==================================================
# Step: 6,000,000
# Fraud seen: 4,815
# Normal seen: 5,995,186
# ROCAUC: 69.94%
# F1: 46.60%
# Recall: 31.19%
# Precision: 92.09%
# Drifts:    51
#
# ==================================================
# Step: 6,100,000
# Fraud seen: 5,807
# Normal seen: 6,094,194
# ROCAUC: 72.89%
# F1: 49.18%
# Recall: 33.48%
# Precision: 92.62%
# Drifts:    68
#
# ==================================================
# Step: 6,200,000
# Fraud seen: 6,349
# Normal seen: 6,193,652
# ROCAUC: 73.62%
# F1: 49.13%
# Recall: 33.44%
# Precision: 92.55%
# Drifts:    77
#
# ==================================================
# Step: 6,300,000
# Fraud seen: 7,501
# Normal seen: 6,292,500
# ROCAUC: 76.29%
# F1: 53.22%
# Recall: 37.24%
# Precision: 93.22%
# Drifts:    90
#
# ==================================================
# FINAL RESULT
# ==================================================
# ROCAUC: 77.57%
# F1: 55.44%
# Recall: 39.33%
# Precision: 93.90%
# Drifts:    96
# Fraud seen: 8,213
# Normal seen: 6,354,407
